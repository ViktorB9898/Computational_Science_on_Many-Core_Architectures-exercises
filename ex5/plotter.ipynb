# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Task 1

# %% [markdown]
# ## a)

# %%
N = [1,5,10,50,100,500,1000,5000,10000,50000,100000]

time_rtx = [4e-06,
4e-06,
4e-06,
4e-06,
4e-06,
4e-06,
5e-06,
9e-06,
1.2e-05,
4.3e-05,
8.2e-05,]

time_k40 = [7e-06,
7e-06,
6e-06,
7e-06,
7e-06,
8e-06,
9e-06,
2.1e-05,
3e-05,
0.000117,
0.000225,]


plt.semilogx(N, time_rtx, label="k40")
plt.semilogx(N, time_k40, label="rtx3060")
plt.xlabel("N")
plt.ylabel("Time [s]")
plt.legend()
plt.grid(True)

# %% [markdown]
# ## b)

# %%
N = [10,100,1000,10000,50000,100000,500000]

time_rtx = [5e-06,
5e-06,
5e-06,
5e-06,
5e-06,
5e-06,
5e-06,
]

time_k40 = [1.1e-05,
1.1e-05,
1.1e-05,
1.1e-05,
1.1e-05,
1e-05,
1.1e-05,
]

mean_rtx = np.mean(time_rtx[0:4])
mean_k40 = np.mean(time_k40[0:4])


plt.semilogx(N, time_rtx, label="rtx3060")
plt.semilogx(N, time_k40, label="k40")
#plt.loglog(N, np.ones(len(N))*mean_rtx, "--")
#plt.loglog(N, np.ones(len(N))*mean_k40, "--")
plt.xlabel("N")
plt.ylabel("Time [s]")
plt.legend()
plt.grid(True)

#print("RTX: Mean of first 5 values:", mean_rtx)
#print("K40: Mean of first 5 values:", mean_k40)

# %% [markdown]
# # c)

# %%
N = [10,50,100,500,1000,5000,10000,50000,100000,500000,1000000,5000000,10000000,50000000,100000000]


bandwidth_rtx = [0.048,
0.24,
0.48,
2.4,
4,
20,
40,
200,
266.667,
285.714,
307.692,
326.975,
330.124,
331.217,
331.446,]

bandwidth_k40 = [0.02,
0.1,
0.2,
1,
2,
10,
20,
92.3077,
104.348,
151.899,
162.162,
167.598,
167.131,
157.356,
163.01,]

plt.semilogx(N,bandwidth_rtx,label="rtx")
plt.semilogx(N,bandwidth_k40,label="k40")
plt.xlabel("N")
plt.ylabel("Bandwidth [GB/s]")
plt.legend()
plt.grid(True)

# %% [markdown]
# # d)

# %%
add_per_second = [1.5873e+08,
1.72414e+08,
1.73611e+08,
1.73792e+08,
1.73931e+08,
1.81294e+08,
1.81364e+08,
1.81362e+08,]

N = [10000,100000,500000,1000000,5000000,10000000,50000000,100000000]

plt.semilogx(N,add_per_second,label="rtx")
#plt.semilogx(N,bandwidth_k40,label="k40")
plt.xlabel("N")
plt.ylabel("atomicAdd / s")
plt.legend()
plt.grid(True)

# %% [markdown]
# # e)

# %%
N = [10000,50000,100000,500000,1000000,5000000,10000000,50000000]


flops_rtx = [13.3333,
18.6047,
19.5122,
26.5781,
28.2187,
22.8311,
20.4473,
19.8128,]

flops_k40 = [5.16129,
6.83761,
7.07965,
10.2828,
11.1111,
11.9564,
12.0873,
12.221,]

plt.semilogx(N,flops_rtx,label="rtx")
plt.semilogx(N,flops_k40,label="k40")
plt.xlabel("N")
plt.ylabel("GFlops / s")
plt.legend()
plt.grid(True)
