# %%
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# # Task 1

# %%
N = [100,500,1000,5000,10000,50000,100000,500000]

bandwidth_a = [0.08,
0.4,
0.8,
4,
7.27273,
33.3333,
53.3333,
111.111,]

bandwidth_b = [0.0363636,
0.181818,
0.363636,
1.81818,
3.63636,
16,
28.5714,
75.4717,]

bandwidth_c = [0.114286,
0.571429,
1.14286,
5,
8,
19.0476,
22.8571,
26.4901,]

time_a = [
1e-05,
1e-05,
1e-05,
1e-05,
1.1e-05,
1.2e-05,
1.5e-05,
3.6e-05,]

time_b = [2.2e-05,
2.2e-05,
2.2e-05,
2.2e-05,
2.2e-05,
2.5e-05,
2.8e-05,
5.3e-05,
]

time_c = [7e-06,
7e-06,
7e-06,
8e-06,
1e-05,
2.1e-05,
3.5e-05,
0.000151,]

time_dot = [1.2e-05,
1.2e-05,
1.2e-05,
1.2e-05,
1.3e-05,
1.3e-05,
1.4e-05,
3.4e-05,
]

plt.loglog(N, bandwidth_c, label="c)")
plt.loglog(N, bandwidth_b, label="b)")
plt.loglog(N, bandwidth_a, label="a)")
plt.xlabel("N")
plt.ylabel("Bandwidth [GB/s]")
plt.legend()
plt.grid(True)

# %%
N_cublas = [
100,   
300,     
1000,  
3000,     
10000,   
30000,
100000,   
300000 ,  
1000000,  
3000000,  
10000000, ]

time_cublas = [
1.7375e-05,
1.7125e-05,
1.75e-05,
1.73125e-05,
1.7625e-05,
1.8e-05,
1.84375e-05,
3.09375e-05,
6.76875e-05,
0.000159812,
0.000490125,]

plt.loglog(N, time_c, label="c)")
plt.loglog(N, time_b, label="b)")
plt.loglog(N, time_a, label="a)")
plt.loglog(N, time_dot, label="dot")
plt.loglog(N_cublas, time_cublas, label="cublas dot")


plt.xlabel("N")
plt.ylabel("Time [s]")
plt.legend()
plt.grid(True)

# %% [markdown]
# # Task 2

# %%
time_8 = [1.8e-05,
1.7e-05,
1.8e-05,
2.5e-05,
3.5e-05,
0.000117,
0.000225,]

time_16 = [3e-05,
3.1e-05,
3.2e-05,
4.6e-05,
6.7e-05,
0.000231,
0.000445,]

time_24 = [4.3e-05,
4.5e-05,
4.6e-05,
6.7e-05,
9.7e-05,
0.000345,
0.000666,]

time_32 = [5.6e-05,
5.8e-05,
6e-05,
8.8e-05,
0.00013,
0.000458,
0.000885,]



N = [1000,5000,10000,50000,100000,500000,1000000]

plt.loglog(N, time_32, label="K = 32")
plt.loglog(N, time_24, label="K = 24")
plt.loglog(N, time_16, label="K = 16")
plt.loglog(N, time_8, label="K = 8")

plt.xlabel("N")
plt.ylabel("Time [s]")
plt.legend()
plt.grid(True)

# %%
t8 = [0.000112,
0.00011,
0.000113,
0.000101,
0.00011,
0.000259,
0.000454,]

t16 = [0.000224,
0.000222,
0.00022,
0.000192,
0.000213,
0.000509,
0.000908,]

t24 = [0.000324,
0.000326,
0.000331,
0.000274,
0.00031,
0.000752,
0.001353,]

t32 = [0.000425,
0.000431,
0.000432,
0.00036,
0.000415,
0.001013,
0.001804,]


time_c_8 = [0.000261,
0.000268,
0.000266,
0.000341,
0.000338,
0.000657,
0.000987,]

time_c_16 = [0.001067,
0.001059,
0.001045,
0.001344,
0.001338,
0.002626,
0.003959,]

time_c_24 = [0.002388,
0.002373,
0.00238,
0.003037,
0.003027,
0.005872,
0.008909,]

time_c_32 = [0.004192,
0.004174,
0.004266,
0.005269,
0.005352,
0.010346,
0.015755,]

plt.loglog(N, time_c_32,"--", label="cublas: K = 32")
plt.loglog(N, time_c_24,"--", label="cublas: K = 24")
plt.loglog(N, time_c_16,"--", label="cublas: K = 16")
plt.loglog(N, time_c_8, "--", label="cublas: K = 8")

plt.xlabel("N")
plt.ylabel("Time [s]")
plt.legend()
plt.grid(True)
