# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time_cl_rtx = [4.8e-05, 0.000192, 0.000374,
               0.00184, 0.00366, 0.018523, 0.037054, 0.184164]

time_cuda_rtx = [2.8e-05,
                 2.8e-05,
                 2.9e-05,
                 5e-05,
                 7.3e-05,
                 0.000258,
                 0.000491,
                 0.002359,
                 ]

time_cl_k40 = [0.0001,0.000382,0.000734,0.003161,0.00609,0.029347,0.058195,0.290069]

time_cuda_k40 = [4.8e-05,
                 4.9e-05,
                 5.2e-05,
                 9.2e-05,
                 0.000135,
                 0.000565,
                 0.000958,
                 0.004868, ]

time_cl_CPU = [0.000227, 0.000495, 0.000914,
               0.006434, 0.011741, 0.084704, 0.194749, 0.983447]

N = [10000, 50000, 100000, 500000, 1000000, 5000000, 10000000, 50000000]

plt.loglog(N, time_cl_rtx, label="RTX openCL")
plt.loglog(N, time_cl_k40, label="K40 openCL")
plt.loglog(N, time_cuda_rtx, "--", label="RTX CUDA")
plt.loglog(N, time_cuda_k40, "--", label="K40 CUDA")
plt.loglog(N, time_cl_CPU, "-.", label="i7 CPU")
plt.ylabel("Time [s]")
plt.xlabel("vector size N")
plt.legend()
