# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## basic cuda a)

# %%
y_1 = [0.0001353,
       0.0001334,
       0.0001273,
       0.0001296,
       0.0001299,
       0.0004032,
       0.0038302,
       0.0382892, ]

y_2 = [0.000101,
       0.0001,
       9.21e-05,
       9.19e-05,
       9.24e-05,
       9.65e-05,
       0.0001633,
       0.0007945, ]

N = [10, 100, 1000, 10000, 100000, 1000000, 10000000, 100000000]


plt.plot(N, y_1, label='cudaMalloc')
plt.plot(N, y_2, label='cudaFree')
plt.xscale('log')
plt.xlabel('N')
plt.ylabel('time')
plt.legend()

# %% [markdown]
# ## basic cuda d

# %%
N = [10,
     50,
     250,
     1250,
     6250,
     31250,
     156250,
     781250,
     3906250,
     ]

y = [2.16e-05,
     2e-05,
     2.02e-05,
     2e-05,
     1.92e-05,
     2.3e-05,
     4.58e-05,
     0.0001506,
     0.000666,
     ]

plt.plot(N, y)
plt.xscale('log')
plt.xlabel('N')
plt.ylabel('time')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## basic cuda e)

# %%
Threads = [16,
           32,
           64, 128, 256, 512, 1024
           ]

y = [0.0084504,
     0.0046038,
     0.0027196,
     0.0018664,
     0.0017358,
     0.0014548,
     0.001506,
     ]

plt.plot(Threads, y)
plt.xscale('log')
plt.xlabel('Threads_per_Block')
plt.ylabel('time')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
