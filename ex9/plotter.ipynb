# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
time_boost = [0.000189,
              0.000162,
              0.000176,
              0.0003,
              0.001537,
              0.024894,
              0.242926, ]

time_thrust = [4.9e-05,
               5e-05,
               4.9e-05,
               5.6e-05,
               5.9e-05,
               0.000333,
               0.001484, ]

time_vexcl = [8.7e-05,
              8e-05,
              8e-05,
              9.8e-05,
              0.000336,
              0.00237,
              0.021612, ]

time_viennacl = [2.9e-05,
                 2.7e-05,
                 2.8e-05,
                 2.7e-05,
                 8.5e-05,
                 0.000356,
                 0.003373, ]

time_CUDA = [2.7e-05,
             2.7e-05,
             2.7e-05,
             2.8e-05,
             3.1e-05,
             7.8e-05,
             0.000497, ]

time_OpenCL = [1.1e-05,
               1.3e-05,
               1.6e-05,
               4.9e-05,
               0.000376,
               0.003663,
               0.036738
               ]


N = [10**k for k in range(1, 8)]

plt.loglog(N, time_boost, label="Boost.Compute")
plt.loglog(N, time_thrust, label="Thrust")
plt.loglog(N, time_vexcl, label="VexCL")
plt.loglog(N, time_viennacl, label="ViennaCL")
plt.loglog(N, time_CUDA, label="Custom CUDA")
plt.loglog(N, time_OpenCL, label="Custom OpenCL")
plt.legend()
plt.xlabel("N")
plt.ylabel("time [s]")
# Out:
# Text(0, 0.5, 'time [s]')
