# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Task 1

# %% [markdown]
# ## a)

# %%
N = [10,100,1000,10000,100000,1000000,10000000,100000000]

time_ex = [
2.3e-05,
2.2e-05,
2.2e-05,
2.2e-05,
3.4e-05,
0.000308,
0.002159,
0.020657,]

time_in_b = [2.8e-05,
2.8e-05,
3.1e-05,
4.8e-05,
0.000372,
0.003667,
0.054262,
0.540893,]

time_in_c = [2.3e-05,
2.3e-05,
2.2e-05,
2.3e-05,
3.4e-05,
0.000307,
0.002157,
0.019915,]


plt.loglog(N, time_ex, "o", label="exclusive")
plt.loglog(N, time_in_b, label="inclusive from b)")
plt.loglog(N, time_in_c, label="inclusive from c)")
plt.xlabel("N")
plt.ylabel("Time [s]")
plt.legend()
plt.grid(True)

# %% [markdown]
# ## b)
