# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Task 1

# %% [markdown]
# ## a)

# %%
N = np.array([10, 25, 50, 75, 100, 250, 500, 750, 1000, 1250])**2

time_custom = [8.09231e-05,
7.67692e-05,
7.58974e-05,
7.54661e-05,
7.52975e-05,
0.000100202,
0.0001586,
0.000318775,
0.000572127,
0.000931971,]

time_classic = [0.000105923,
0.000100949,
0.000100513,
0.000100644,
0.000100278,
0.000120733,
0.000223489,
0.000390673,
0.000657263,
0.00102226,]



plt.loglog(N, time_custom, label="pipelined")
plt.loglog(N, time_classic, label="classical")
plt.xlabel("N")
plt.ylabel("Time per iteration [s]")
plt.legend()
plt.grid(True)
